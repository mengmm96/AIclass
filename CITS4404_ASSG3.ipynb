# %% [markdown]
# <a href="https://colab.research.google.com/github/mengmm96/AIclass/blob/master/CITS4404_ASSG3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #CITS4404 - ASSIGNMENT 3
#
# ## Zimin Meng 22665473

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# import required libraries
import matplotlib.pyplot as plt
import numpy as np
import pickle as pkl
import torch
from torchvision import datasets
from torchvision import transforms
import scipy.io as sio

# %matplotlib inline

# %%
from scipy.io import loadmat


#compare the shape of image set
#print(extra.shape): (32, 32, 3, 50)
#print(train['X'].shape) : (32, 32, 3, 73257)

# Tensor transform, will use to transform data to Tensor datatype
transform = transforms.ToTensor()

svhn_train = datasets.SVHN(root='data/', split='train', download= True, transform=transform)
#Alternative: train = loadmat('data/train_32x32.mat')
#train_s = svhn_train['X']
# Out:
# Downloading http://ufldl.stanford.edu/housenumbers/train_32x32.mat to data/train_32x32.mat
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))

# %%
#load extra image set which contains 50 new images and have been transformed
extra = sio.loadmat('/content/drive/My Drive/extra.mat')
extra_s = extra['A']

# shape of extra_s i (32, 32, 3, 50), in HWCN format but numpy array in svhn_train is NCHW so we need to transpose it
# shape of extra data after this operation become after transpose(50, 3, 32, 32) 
extra_data_np = extra_s.transpose(3, 2, 0, 1)

#append extra data set and training data set
training_np = np.concatenate((extra_data_np, svhn_train.data), axis = 0)
# training_np.shape check the shape:(73307, 3, 32, 32)

# %%
#Visualize some extra images

def show_extra_images():
    # randomly generate 10 sample image from 
    idx = np.random.randint(0, extra_s.shape[3], size=10)
    fig, axes = plt.subplots(1, 10, sharex=True, sharey=True, figsize=(20, 4), )
    for ii, ax in zip(idx, axes.flatten()):
        ax.imshow(extra_s[:, :, :, ii], aspect='equal')
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
    plt.subplots_adjust(wspace=0, hspace=0)
    plt.show()
show_extra_images()

# %%
# convert numpy data to torch data
training_ts = torch.Tensor(training_np)
# convert tensor data to a dataset can be used for dataloader
train = torch.utils.data.TensorDataset(training_ts)

batch_size = 128
num_workers = 0

# create DataLoaders for SVHN dataset - help batch data into batches of specific size
train_loader = torch.utils.data.DataLoader(dataset=train,
                                          batch_size=batch_size,
                                          shuffle=True,
                                          num_workers=num_workers)

# %%
# take one batch of training images
#remove labels, due to extra images don't have labels
dataiter = iter(train_loader)
images= dataiter.next()
print(type(images))
print(type(images[0]))
# Out:
# <class 'list'>
# <class 'torch.Tensor'>

# %%
#Plot the images
fig = plt.figure(figsize=(25, 4))
plot_size=20
for idxx in np.arange(plot_size):
    ax = fig.add_subplot(2, plot_size/2, idxx+1, xticks=[], yticks=[])
    pics = images[0]
    ax.imshow(np.transpose(pics[idxx], (1, 2, 0))/255)

# %%
## current range
img = images[0]

print('Min: ', img.min())
print('Max: ', img.max())
# Out:
# Min:  tensor(0.)
# Max:  tensor(255.)

# %%
# The output of our G will be tanh activated e.i. on a range from [-1 1], 
# We need to rescale training images to that range. (Currently: [0 1])
def scale(xx, feature_range=(-1, 1)):
    ''' INPUT: image xx scaled to [0 255]
       OUTPUT: image scaled [-1 1] '''
    # assume x is scaled to (0, 1)
    # scale to feature_range and return scaled x
    min, max = feature_range
    xx = xx/255
    xx = xx * (max - min) + min
    return xx

# %%
# scale image
scaled_img = scale(img)

print('Scaled min: ', scaled_img.min())
print('Scaled max: ', scaled_img.max())
# Out:
# Scaled min:  tensor(-1.)
# Scaled max:  tensor(1.)

# %% [markdown]
# Home numbers dataset is more complex than MNIST, we will train a deeper network to identify patterns in these images and generate new ones.
# Use a series of convolutional and transpose convolutional layers in the discriminator and generator respectively.
# Use batch normalization to get convolutional networks to train faster/beter.

# %%
import torch.nn as nn
import torch.nn.functional as F

# Each layer should be convolution -> batch norm (optional) -> leaky ReLU
# conv function will put these layers together sequentialy.
# Use PyTorch's Sequential container which takes in a list of layers and creates 
# layers according to the order that they are passed in to the Sequential constructor.
# A strided convolutional layer and an optional batch norm layer
#
# https://pytorch.org/docs/stable/nn.html#batchnorm2d
# https://pytorch.org/docs/stable/nn.html#sequential
#
# We will use kernel_size = 4 & stride = 2, will reduce size of image by 2
def conv(in_channels, out_channels, kernel_size, stride=2, padding=1, batch_norm=True):
    """Creates a convolutional layer, with optional batch normalization.
    """
    layers = []
    conv_layer = nn.Conv2d(in_channels, out_channels, 
                           kernel_size, stride, padding, bias=False)
    # bias is set to False, so the layers are not offset by any amount
    # append conv layer
    layers.append(conv_layer)

    if batch_norm:
        # append batchnorm layer
        layers.append(nn.BatchNorm2d(out_channels))
     
    # using Sequential container
    return nn.Sequential(*layers)

# %%
# Use batch normalization with nn.BatchNorm2d on each layer except 
# the 1st convolutional layer and final linear output layer.
# In the DCGAN paper, they did all the downsampling using only strided convolutional layers with no maxpooling layers

class Discriminator(nn.Module):
    def __init__(self, conv_dim=32):
        super(Discriminator, self).__init__()

        # complete init function
        self.conv_dim = conv_dim

        # 32x32 input, 16x16 output
        self.conv1 = conv(3, conv_dim, 4, batch_norm= False) # 1st layer, no batch_norm 
        self.conv2 = conv(conv_dim, conv_dim*2, 4)   # 8x8 output
        self.conv3 = conv(conv_dim*2, conv_dim*4, 4) # 4x4 output
        
        # final fully-connected layer - produces 1 output (par 2)
        self.fc = nn.Linear(conv_dim*4*4*4, 1)

    def forward(self, xx):
        # all hidden layers + leaky relu activation
        out = F.leaky_relu(self.conv1(xx),  0.2)
        out = F.leaky_relu(self.conv2(out), 0.2)
        out = F.leaky_relu(self.conv3(out), 0.2)
        
        # flatten
        out = out.view(-1, self.conv_dim*4*4*4)
        
        # final output layer
        out = self.fc(out)        
        return out

# %%
# define a function that will allow us to do:
# transpose convolution -> batch norm (optional: T/F) -> ReLU
# Use kernel_size 4 & stride 2 for transpose convolutions

def deconv(in_channels, out_channels, kernel_size, stride=2, padding=1, batch_norm=True):
    """Create a transposed-convolutional layer with optional batch normalization """
    # create a sequence of transpose + optional batch norm layers
    layers = [] # empty list of layers
    transpose_conv_layer = nn.ConvTranspose2d(in_channels, out_channels, 
                                              kernel_size, stride, padding, bias=False)
    # append transpose convolutional layer
    layers.append(transpose_conv_layer)
    
    if batch_norm:
        # append batchnorm layer
        layers.append(nn.BatchNorm2d(out_channels))
        
    return nn.Sequential(*layers)

# %%
# In G 1st layer is a fully connected layer which is reshaped into a deep and narrow layer, eg. 4x4x512
# Then use batch norm & leaky ReLU activation
# Next is a series of transpose convolutional layers where you typically have the depth and double the width and height of the previous layer
# Apply batch normalization and ReLU to all but the last hidden layer. Where we apply a tanh activation

# Input: randomly generated vector z
# Output tanh values of size 32x32 which is the size of the SVHN images

class Generator(nn.Module):
    
    def __init__(self, z_size, conv_dim=32):
        super(Generator, self).__init__()

        # complete init function
        
        self.conv_dim = conv_dim
        
        # first fully-connected layer, 
        # params: latent verctor z & produces a layer 4x4x128
        #         4x4 part defined in the forward step below
        self.fc = nn.Linear(z_size, conv_dim*4*4*4)

        # transpose conv layers, kernel_size = 4,
        # desired depth for RGB image is 3
        self.t_conv1 = deconv(conv_dim*4, conv_dim*2, 4)
        self.t_conv2 = deconv(conv_dim*2, conv_dim, 4)
        self.t_conv3 = deconv(conv_dim, 3, 4, batch_norm=False)
        

    def forward(self, xx):
        # fully-connected + reshape 
        out = self.fc(xx)
        # params: batch_size, depth, 4, 4
        # -1 is a place holder for batch size
        # 128 - depth as defined by the convolutional dimention
        out = out.view(-1, self.conv_dim*4, 4, 4) # (batch_size, depth, 4, 4)
        
        # hidden transpose conv layers + relu
        out = F.relu(self.t_conv1(out))
        out = F.relu(self.t_conv2(out))
        
        # last layer + tanh activation
        out = self.t_conv3(out)
        out = F.tanh(out)
        
        return out

# %%
# define hyperparams
conv_dim = 32
z_size = 100

# instantiate D and G
D = Discriminator(conv_dim)
G = Generator(z_size=z_size, conv_dim=conv_dim)

print(D)
print()
print(G)
# Out:
# Discriminator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fc): Linear(in_features=2048, out_features=1, bias=True)
# )
#
# Generator(
#   (fc): Linear(in_features=100, out_features=2048, bias=True)
#   (t_conv1): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (t_conv2): Sequential(
#     (0): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (t_conv3): Sequential(
#     (0): ConvTranspose2d(32, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
# )

# %%
train_on_gpu = torch.cuda.is_available()

if train_on_gpu:
    # move models to GPU
    G.cuda()
    D.cuda()
    print('GPU available for training. Models moved to GPU')
else:
    print('Training on CPU...')
# Out:
# GPU available for training. Models moved to GPU

# %%
# Define Losses
# For D the total loss is the sum of the losses for real and fake images:
#     d_loss = d_real_loss + d_fake_loss
# The losses will by binary cross entropy loss with logits (BCEWithLogitsLoss). 
# BCEWithLogitsLoss combines a sigmoid activation function and a binary cross entropy loss
# We want D to output 1 for real images and 0 for fake images, make sure the losses to reflect that.
#
# For real images we want D(real_images) = 1, i.e. classify real images as = 1. 
# D's loss for the fake data is D(fake_images) = 0, where fake images are G's output, fake_images = G(z).
#
# For G the loss is similar but with labels flipped. G's goal is to get D(fake_images) = 1. 
# In this case, the labels are flipped to represent that the generator is trying to fool the discriminator 
# into thinking that the fake images it generates are real


def real_loss(D_out, smooth=False):
    batch_size = D_out.size(0)
    # label smoothing
    if smooth:
        # smooth, real labels = 0.9
        labels = torch.ones(batch_size)*0.9
    else:
        labels = torch.ones(batch_size) # real labels = 1
    # move labels to GPU if available     
    if train_on_gpu:
        labels = labels.cuda()
    # binary cross entropy with logits loss
    criterion = nn.BCEWithLogitsLoss()
    # calculate loss
    loss = criterion(D_out.squeeze(), labels)
    return loss

def fake_loss(D_out):
    batch_size = D_out.size(0)
    labels = torch.zeros(batch_size) # fake labels = 0
    if train_on_gpu:
        labels = labels.cuda()
    criterion = nn.BCEWithLogitsLoss()
    # calculate loss
    loss = criterion(D_out.squeeze(), labels)
    return loss

# %%
# Optimisers, similar to what we did before

import torch.optim as optim

# params suggested to be good in the DCGAN paper 
# GANs can be very seinsitive to small changes in parameter values
# Check out some options in the DCGAN paper:
#    https://arxiv.org/pdf/1511.06434.pdf

#learning rate initially set as lr and then varies as epoch increases
lr = 0.01
beta1=0.5
beta2=0.999 # default value


# Create optimizers for the discriminator and generator
d_optimizer = optim.Adam(D.parameters(), lr, [beta1, beta2])
g_optimizer = optim.Adam(G.parameters(), lr, [beta1, beta2])

    
def adjust_learning_rate(d_optimizer, g_optimizer, new_lr):
    for d_param in d_optimizer.param_groups:
      d_param['lr'] = new_lr
    for g_param in g_optimizer.param_groups:
     g_param['lr'] = new_lr

# %%
d_optimizer
# Out:
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: [0.5, 0.999]
#     eps: 1e-08
#     lr: 0.01
#     weight_decay: 0
# )

# %%
# Discriminator training
#   Compute the discriminator loss on real, training images
#   Generate fake images
#   Compute the discriminator loss on fake, generated images
#   Add up real and fake loss
#   Perform backpropagation + an optimization step to update the discriminator's weights
#
# Generator training
#   Generate fake images
#   Compute the discriminator loss on fake images, using flipped labels!
#   Perform backpropagation + an optimization step to update the generator's weights


import pickle as pkl # to save intermediate fake images

# training hyperparams
num_epochs = 100 # will run for a 2-4 hours

# keep track of loss and fake samples
samples = []
losses = []
print_every = 100

# Get some fixed data for evaluating the model's performance as we train
# Keep these images constant
sample_size=16
fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
fixed_z = torch.from_numpy(fixed_z).float()

# train the network
for epoch in range(num_epochs):
    lr = 0.01
    if epoch > 20:
        lr = 0.005
        adjust_learning_rate(d_optimizer, g_optimizer, lr)
    if epoch > 40:
        lr = 0.002
        adjust_learning_rate(d_optimizer, g_optimizer, lr)
    if epoch > 60:
        lr = 0.001
        adjust_learning_rate(d_optimizer, g_optimizer, lr)
    if epoch > 80:
        lr = 0.0005
        adjust_learning_rate(d_optimizer, g_optimizer, lr)


    for batch_i, real_images in enumerate(train_loader):
        real_images = real_images[0]        
        batch_size = real_images.size(0)
        
        # important rescaling step
        real_images = scale(real_images)
        
        # train D
        d_optimizer.zero_grad()
        
        # 1. Train with real images
        # Compute the D losses on real images 
        if train_on_gpu:
            real_images = real_images.cuda()
        
        D_real = D(real_images)
        d_real_loss = real_loss(D_real)
        
        # 2. Train with fake images
        # Generate fake images
        zz = np.random.uniform(-1, 1, size=(batch_size, z_size))
        zz = torch.from_numpy(zz).float()
        # move to GPU, if available
        if train_on_gpu:
            zz = zz.cuda()
        fake_images = G(zz)
        
        # Compute the D losses on fake images            
        D_fake = D(fake_images)
        d_fake_loss = fake_loss(D_fake)
        
        # add up loss and perform backprop
        d_loss = d_real_loss + d_fake_loss
        d_loss.backward()
        d_optimizer.step()
        
        
        # train G
        g_optimizer.zero_grad()
        
        # 1. Train with fake images and flipped labels 
        # Generate fake images
        zz = np.random.uniform(-1, 1, size=(batch_size, z_size))
        zz = torch.from_numpy(zz).float()
        if train_on_gpu:
            zz = zz.cuda()
        fake_images = G(zz)
        
        # Compute the D losses on fake images 
        # using flipped labels
        D_fake = D(fake_images)
        g_loss = real_loss(D_fake) # use real loss to flip labels
        
        # perform backprop
        g_loss.backward()
        g_optimizer.step()

        # Print some loss stats
        if batch_i % print_every == 0:
            # append D loss and G loss
            losses.append((d_loss.item(), g_loss.item()))
            # print discriminator and generator loss
            print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                    epoch+1, num_epochs, d_loss.item(), g_loss.item()))

    
    # AFTER EACH EPOCH    
    # generate and save fake images
    G.eval() # eval mode for generating samples
    # eval mode - batch_norm & drop out behave differently in generating new samples
    # batch_norm should use population statistics instead of batch statistics in eval
    # dropout should not drop any nodes during testing
    
    if train_on_gpu:
        fixed_z = fixed_z.cuda()
    samples_z = G(fixed_z)
    samples.append(samples_z)
    G.train() # switch back to training mode

# Save training generator samples
with open('fake_images.pkl', 'wb') as f:
    pkl.dump(samples, f)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1614: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# Epoch [    1/  100] | d_loss: 1.3931 | g_loss: 5.8700
# Epoch [    1/  100] | d_loss: 0.8224 | g_loss: 3.2433
# Epoch [    1/  100] | d_loss: 0.8910 | g_loss: 1.6005
# Epoch [    1/  100] | d_loss: 1.2637 | g_loss: 0.8224
# Epoch [    1/  100] | d_loss: 1.1494 | g_loss: 1.3303
# Epoch [    1/  100] | d_loss: 1.5669 | g_loss: 1.0898
# Epoch [    2/  100] | d_loss: 1.2282 | g_loss: 1.3194
# Epoch [    2/  100] | d_loss: 1.2490 | g_loss: 1.0476
# Epoch [    2/  100] | d_loss: 1.0997 | g_loss: 1.7353
# Epoch [    2/  100] | d_loss: 1.3501 | g_loss: 0.7052
# Epoch [    2/  100] | d_loss: 1.1648 | g_loss: 1.2131
# Epoch [    2/  100] | d_loss: 1.2634 | g_loss: 1.2921
# Epoch [    3/  100] | d_loss: 1.2745 | g_loss: 0.9100
# Epoch [    3/  100] | d_loss: 1.2469 | g_loss: 1.2867
# Epoch [    3/  100] | d_loss: 1.0101 | g_loss: 1.3807
# Epoch [    3/  100] | d_loss: 1.1481 | g_loss: 1.1374
# Epoch [    3/  100] | d_loss: 1.2874 | g_loss: 1.2193
# Epoch [    3/  100] | d_loss: 1.1656 | g_loss: 1.0502
# Epoch [    4/  100] | d_loss: 1.3726 | g_loss: 0.9928
# Epoch [    4/  100] | d_loss: 1.1772 | g_loss: 1.4410
# Epoch [    4/  100] | d_loss: 1.2997 | g_loss: 1.2866
# Epoch [    4/  100] | d_loss: 1.1839 | g_loss: 1.7320
# Epoch [    4/  100] | d_loss: 1.3049 | g_loss: 0.7191
# Epoch [    4/  100] | d_loss: 2.7382 | g_loss: 1.0770
# Epoch [    5/  100] | d_loss: 1.1776 | g_loss: 1.4999
# Epoch [    5/  100] | d_loss: 1.0997 | g_loss: 2.0256
# Epoch [    5/  100] | d_loss: 1.1752 | g_loss: 1.7348
# Epoch [    5/  100] | d_loss: 1.2016 | g_loss: 1.2910
# Epoch [    5/  100] | d_loss: 1.1277 | g_loss: 1.4078
# Epoch [    5/  100] | d_loss: 0.9693 | g_loss: 2.0995
# Epoch [    6/  100] | d_loss: 1.4599 | g_loss: 1.1454
# Epoch [    6/  100] | d_loss: 0.9484 | g_loss: 2.8934
# Epoch [    6/  100] | d_loss: 0.9846 | g_loss: 2.5893
# Epoch [    6/  100] | d_loss: 0.9786 | g_loss: 2.3942
# Epoch [    6/  100] | d_loss: 0.9377 | g_loss: 2.0204
# Epoch [    6/  100] | d_loss: 0.7959 | g_loss: 1.6476
# Epoch [    7/  100] | d_loss: 0.6623 | g_loss: 1.9688
# Epoch [    7/  100] | d_loss: 0.8847 | g_loss: 1.0094
# Epoch [    7/  100] | d_loss: 0.8924 | g_loss: 1.9163
# Epoch [    7/  100] | d_loss: 0.7028 | g_loss: 2.9305
# Epoch [    7/  100] | d_loss: 0.6738 | g_loss: 2.2618
# Epoch [    7/  100] | d_loss: 0.5037 | g_loss: 1.3513
# Epoch [    8/  100] | d_loss: 0.5269 | g_loss: 2.6628
# Epoch [    8/  100] | d_loss: 0.4373 | g_loss: 2.1858
# Epoch [    8/  100] | d_loss: 0.8654 | g_loss: 1.5267
# Epoch [    8/  100] | d_loss: 0.5106 | g_loss: 3.2231
# Epoch [    8/  100] | d_loss: 0.6782 | g_loss: 2.4002
# Epoch [    8/  100] | d_loss: 0.4288 | g_loss: 2.0556
# Epoch [    9/  100] | d_loss: 0.5106 | g_loss: 2.3576
# Epoch [    9/  100] | d_loss: 0.7673 | g_loss: 1.7206
# Epoch [    9/  100] | d_loss: 0.6169 | g_loss: 2.6902
# Epoch [    9/  100] | d_loss: 0.5851 | g_loss: 1.9343
# Epoch [    9/  100] | d_loss: 0.8687 | g_loss: 3.6496
# Epoch [    9/  100] | d_loss: 0.5324 | g_loss: 2.1318
# Epoch [   10/  100] | d_loss: 0.6776 | g_loss: 2.7034
# Epoch [   10/  100] | d_loss: 0.3632 | g_loss: 3.0831
# Epoch [   10/  100] | d_loss: 0.3001 | g_loss: 3.5726
# Epoch [   10/  100] | d_loss: 0.4274 | g_loss: 3.5948
# Epoch [   10/  100] | d_loss: 0.7281 | g_loss: 5.7111
# Epoch [   10/  100] | d_loss: 0.6128 | g_loss: 2.6876
# Epoch [   11/  100] | d_loss: 0.3800 | g_loss: 3.6438
# Epoch [   11/  100] | d_loss: 0.3850 | g_loss: 2.9529
# Epoch [   11/  100] | d_loss: 0.7504 | g_loss: 3.7002
# Epoch [   11/  100] | d_loss: 0.3437 | g_loss: 3.0398
# Epoch [   11/  100] | d_loss: 0.3863 | g_loss: 2.9031
# Epoch [   11/  100] | d_loss: 1.4773 | g_loss: 8.6689
# Epoch [   12/  100] | d_loss: 0.2427 | g_loss: 5.1201
# Epoch [   12/  100] | d_loss: 0.4008 | g_loss: 4.8903
# Epoch [   12/  100] | d_loss: 0.1922 | g_loss: 3.9639
# Epoch [   12/  100] | d_loss: 0.4199 | g_loss: 3.8767
# Epoch [   12/  100] | d_loss: 0.5047 | g_loss: 3.1752
# Epoch [   12/  100] | d_loss: 0.3670 | g_loss: 4.0558
# Epoch [   13/  100] | d_loss: 0.2297 | g_loss: 4.6556
# Epoch [   13/  100] | d_loss: 0.5078 | g_loss: 2.1217
# Epoch [   13/  100] | d_loss: 0.2226 | g_loss: 3.8719
# Epoch [   13/  100] | d_loss: 0.3043 | g_loss: 4.4243
# Epoch [   13/  100] | d_loss: 0.1904 | g_loss: 3.6809
# Epoch [   13/  100] | d_loss: 0.3988 | g_loss: 4.1507
# Epoch [   14/  100] | d_loss: 0.1337 | g_loss: 5.0581
# Epoch [   14/  100] | d_loss: 0.4261 | g_loss: 6.0213
# Epoch [   14/  100] | d_loss: 0.5657 | g_loss: 2.0128
# Epoch [   14/  100] | d_loss: 0.4067 | g_loss: 2.5917
# Epoch [   14/  100] | d_loss: 0.0946 | g_loss: 3.2047
# Epoch [   14/  100] | d_loss: 0.1042 | g_loss: 5.4267
# Epoch [   15/  100] | d_loss: 0.3958 | g_loss: 6.5597
# Epoch [   15/  100] | d_loss: 0.4409 | g_loss: 6.5991
# Epoch [   15/  100] | d_loss: 0.0733 | g_loss: 6.3353
# Epoch [   15/  100] | d_loss: 3.6532 | g_loss: 10.9659
# Epoch [   15/  100] | d_loss: 0.2633 | g_loss: 4.3689
# Epoch [   15/  100] | d_loss: 0.2682 | g_loss: 3.1967
# Epoch [   16/  100] | d_loss: 0.1176 | g_loss: 3.5514
# Epoch [   16/  100] | d_loss: 1.0541 | g_loss: 2.3049
# Epoch [   16/  100] | d_loss: 0.7789 | g_loss: 9.0318
# Epoch [   16/  100] | d_loss: 0.2052 | g_loss: 3.5544
# Epoch [   16/  100] | d_loss: 0.3472 | g_loss: 2.8955
# Epoch [   16/  100] | d_loss: 1.6365 | g_loss: 8.9084
# Epoch [   17/  100] | d_loss: 0.6820 | g_loss: 7.4540
# Epoch [   17/  100] | d_loss: 0.4038 | g_loss: 4.6411
# Epoch [   17/  100] | d_loss: 0.1539 | g_loss: 5.3293
# Epoch [   17/  100] | d_loss: 0.1432 | g_loss: 3.6164
# Epoch [   17/  100] | d_loss: 0.2244 | g_loss: 3.2220
# Epoch [   17/  100] | d_loss: 0.1153 | g_loss: 4.5323
# Epoch [   18/  100] | d_loss: 0.1566 | g_loss: 5.1932
# Epoch [   18/  100] | d_loss: 2.4307 | g_loss: 0.2942
# Epoch [   18/  100] | d_loss: 0.1497 | g_loss: 3.7087
# Epoch [   18/  100] | d_loss: 0.3342 | g_loss: 6.4883
# Epoch [   18/  100] | d_loss: 0.2290 | g_loss: 4.3052
# Epoch [   18/  100] | d_loss: 0.3624 | g_loss: 5.5807
# Epoch [   19/  100] | d_loss: 1.7388 | g_loss: 15.3400
# Epoch [   19/  100] | d_loss: 0.2352 | g_loss: 6.4589
# Epoch [   19/  100] | d_loss: 0.8886 | g_loss: 5.6951
# Epoch [   19/  100] | d_loss: 0.1349 | g_loss: 4.5895
# Epoch [   19/  100] | d_loss: 0.3965 | g_loss: 5.7764
# Epoch [   19/  100] | d_loss: 0.0474 | g_loss: 7.2843
# Epoch [   20/  100] | d_loss: 0.4007 | g_loss: 7.4981
# Epoch [   20/  100] | d_loss: 0.2084 | g_loss: 5.8929
# Epoch [   20/  100] | d_loss: 0.2534 | g_loss: 4.3898
# Epoch [   20/  100] | d_loss: 1.4043 | g_loss: 9.4456
# Epoch [   20/  100] | d_loss: 0.2222 | g_loss: 4.0290
# Epoch [   20/  100] | d_loss: 0.6391 | g_loss: 8.9250
# Epoch [   21/  100] | d_loss: 0.1529 | g_loss: 5.4032
# Epoch [   21/  100] | d_loss: 0.1808 | g_loss: 5.9600
# Epoch [   21/  100] | d_loss: 0.0321 | g_loss: 7.2155
# Epoch [   21/  100] | d_loss: 0.1646 | g_loss: 7.6541
# Epoch [   21/  100] | d_loss: 0.8537 | g_loss: 3.6712
# Epoch [   21/  100] | d_loss: 0.0731 | g_loss: 5.4056
# Epoch [   22/  100] | d_loss: 0.1238 | g_loss: 5.8732
# Epoch [   22/  100] | d_loss: 0.0222 | g_loss: 5.4857
# Epoch [   22/  100] | d_loss: 0.0751 | g_loss: 4.4030
# Epoch [   22/  100] | d_loss: 0.0807 | g_loss: 6.3159
# Epoch [   22/  100] | d_loss: 0.0349 | g_loss: 5.2308
# Epoch [   22/  100] | d_loss: 0.1235 | g_loss: 8.1231
# Epoch [   23/  100] | d_loss: 0.0852 | g_loss: 5.2547
# Epoch [   23/  100] | d_loss: 0.2673 | g_loss: 8.8573
# Epoch [   23/  100] | d_loss: 0.0817 | g_loss: 6.7820
# Epoch [   23/  100] | d_loss: 0.0227 | g_loss: 7.3950
# Epoch [   23/  100] | d_loss: 0.0343 | g_loss: 7.6350
# Epoch [   23/  100] | d_loss: 0.0213 | g_loss: 6.4567
# Epoch [   24/  100] | d_loss: 0.1046 | g_loss: 4.8098
# Epoch [   24/  100] | d_loss: 0.0335 | g_loss: 4.6717
# Epoch [   24/  100] | d_loss: 0.0606 | g_loss: 5.7480
# Epoch [   24/  100] | d_loss: 0.0548 | g_loss: 5.3745
# Epoch [   24/  100] | d_loss: 0.0677 | g_loss: 7.1090
# Epoch [   24/  100] | d_loss: 0.0450 | g_loss: 6.4656
# Epoch [   25/  100] | d_loss: 0.1432 | g_loss: 4.5788
# Epoch [   25/  100] | d_loss: 0.0535 | g_loss: 8.3467
# Epoch [   25/  100] | d_loss: 0.4180 | g_loss: 3.0082
# Epoch [   25/  100] | d_loss: 0.2498 | g_loss: 7.0771
# Epoch [   25/  100] | d_loss: 0.0372 | g_loss: 4.8958
# Epoch [   25/  100] | d_loss: 0.0660 | g_loss: 4.2663
# Epoch [   26/  100] | d_loss: 0.0505 | g_loss: 5.7498
# Epoch [   26/  100] | d_loss: 0.0431 | g_loss: 5.9477
# Epoch [   26/  100] | d_loss: 0.3717 | g_loss: 4.9558
# Epoch [   26/  100] | d_loss: 0.1105 | g_loss: 4.7783
# Epoch [   26/  100] | d_loss: 0.0317 | g_loss: 4.1525
# Epoch [   26/  100] | d_loss: 0.0213 | g_loss: 7.1655
# Epoch [   27/  100] | d_loss: 0.0937 | g_loss: 6.5094
# Epoch [   27/  100] | d_loss: 0.0181 | g_loss: 6.5863
# Epoch [   27/  100] | d_loss: 0.0180 | g_loss: 8.3583
# Epoch [   27/  100] | d_loss: 0.0253 | g_loss: 7.3138
# Epoch [   27/  100] | d_loss: 0.0283 | g_loss: 5.6779
# Epoch [   27/  100] | d_loss: 0.0170 | g_loss: 8.1473
# Epoch [   28/  100] | d_loss: 0.1089 | g_loss: 5.4121
# Epoch [   28/  100] | d_loss: 0.0832 | g_loss: 7.2677
# Epoch [   28/  100] | d_loss: 0.5007 | g_loss: 5.7498
# Epoch [   28/  100] | d_loss: 0.3116 | g_loss: 4.4638
# Epoch [   28/  100] | d_loss: 0.0583 | g_loss: 6.1844
# Epoch [   28/  100] | d_loss: 0.0770 | g_loss: 6.8374
# Epoch [   29/  100] | d_loss: 0.0268 | g_loss: 5.9867
# Epoch [   29/  100] | d_loss: 0.0236 | g_loss: 7.1773
# Epoch [   29/  100] | d_loss: 0.0246 | g_loss: 6.0042
# Epoch [   29/  100] | d_loss: 0.0329 | g_loss: 8.9360
# Epoch [   29/  100] | d_loss: 0.0117 | g_loss: 5.7460
# Epoch [   29/  100] | d_loss: 0.0678 | g_loss: 6.8897
# Epoch [   30/  100] | d_loss: 0.0700 | g_loss: 7.8161
# Epoch [   30/  100] | d_loss: 0.0135 | g_loss: 8.1076
# Epoch [   30/  100] | d_loss: 0.0399 | g_loss: 6.5837
# Epoch [   30/  100] | d_loss: 0.2278 | g_loss: 2.8253
# Epoch [   30/  100] | d_loss: 0.0306 | g_loss: 7.3325
# Epoch [   30/  100] | d_loss: 0.3849 | g_loss: 3.9377
# Epoch [   31/  100] | d_loss: 0.1091 | g_loss: 6.8000
# Epoch [   31/  100] | d_loss: 0.0732 | g_loss: 5.0395
# Epoch [   31/  100] | d_loss: 0.0251 | g_loss: 7.9458
# Epoch [   31/  100] | d_loss: 0.0274 | g_loss: 6.6124
# Epoch [   31/  100] | d_loss: 0.0555 | g_loss: 7.7365
# Epoch [   31/  100] | d_loss: 0.0142 | g_loss: 8.9581
# Epoch [   32/  100] | d_loss: 0.0293 | g_loss: 6.7941
# Epoch [   32/  100] | d_loss: 0.2294 | g_loss: 7.6870
# Epoch [   32/  100] | d_loss: 0.0588 | g_loss: 5.7363
# Epoch [   32/  100] | d_loss: 0.1271 | g_loss: 8.0412
# Epoch [   32/  100] | d_loss: 0.0113 | g_loss: 8.0874
# Epoch [   32/  100] | d_loss: 0.4888 | g_loss: 4.8430
# Epoch [   33/  100] | d_loss: 0.0609 | g_loss: 7.3042
# Epoch [   33/  100] | d_loss: 0.0177 | g_loss: 7.7932
# Epoch [   33/  100] | d_loss: 0.0196 | g_loss: 7.6851
# Epoch [   33/  100] | d_loss: 0.1602 | g_loss: 5.9709
# Epoch [   33/  100] | d_loss: 0.0723 | g_loss: 6.2461
# Epoch [   33/  100] | d_loss: 0.0587 | g_loss: 7.7746
# Epoch [   34/  100] | d_loss: 0.0906 | g_loss: 7.8052
# Epoch [   34/  100] | d_loss: 0.3228 | g_loss: 7.4597
# Epoch [   34/  100] | d_loss: 0.0161 | g_loss: 10.0778
# Epoch [   34/  100] | d_loss: 0.0237 | g_loss: 8.4277
# Epoch [   34/  100] | d_loss: 0.0448 | g_loss: 10.9290
# Epoch [   34/  100] | d_loss: 0.0518 | g_loss: 7.4009
# Epoch [   35/  100] | d_loss: 0.1743 | g_loss: 5.8336
# Epoch [   35/  100] | d_loss: 0.0975 | g_loss: 8.9800
# Epoch [   35/  100] | d_loss: 0.0690 | g_loss: 6.2016
# Epoch [   35/  100] | d_loss: 0.0319 | g_loss: 7.5225
# Epoch [   35/  100] | d_loss: 0.0121 | g_loss: 7.1656
# Epoch [   35/  100] | d_loss: 0.0202 | g_loss: 7.4491
# Epoch [   36/  100] | d_loss: 0.0196 | g_loss: 7.2238
# Epoch [   36/  100] | d_loss: 0.1887 | g_loss: 7.6853
# Epoch [   36/  100] | d_loss: 0.2317 | g_loss: 6.2965
# Epoch [   36/  100] | d_loss: 0.0349 | g_loss: 6.7780
# Epoch [   36/  100] | d_loss: 0.0504 | g_loss: 6.2743
# Epoch [   36/  100] | d_loss: 0.0209 | g_loss: 8.7806
# Epoch [   37/  100] | d_loss: 0.0137 | g_loss: 8.0632
# Epoch [   37/  100] | d_loss: 0.0506 | g_loss: 6.0907
# Epoch [   37/  100] | d_loss: 0.0345 | g_loss: 6.9242
# Epoch [   37/  100] | d_loss: 0.0154 | g_loss: 7.5163
# Epoch [   37/  100] | d_loss: 0.1284 | g_loss: 6.3140
# Epoch [   37/  100] | d_loss: 0.1213 | g_loss: 6.9182
# Epoch [   38/  100] | d_loss: 0.0128 | g_loss: 7.9824
# Epoch [   38/  100] | d_loss: 0.0729 | g_loss: 6.1435
# Epoch [   38/  100] | d_loss: 0.2935 | g_loss: 3.4828
# Epoch [   38/  100] | d_loss: 0.0623 | g_loss: 8.3524
# Epoch [   38/  100] | d_loss: 0.2315 | g_loss: 6.1887
# Epoch [   38/  100] | d_loss: 0.0216 | g_loss: 6.0144
# Epoch [   39/  100] | d_loss: 0.0069 | g_loss: 9.2104
# Epoch [   39/  100] | d_loss: 0.1581 | g_loss: 7.4268
# Epoch [   39/  100] | d_loss: 0.1307 | g_loss: 6.6691
# Epoch [   39/  100] | d_loss: 0.1436 | g_loss: 5.8682
# Epoch [   39/  100] | d_loss: 0.0506 | g_loss: 8.0596
# Epoch [   39/  100] | d_loss: 0.5326 | g_loss: 9.9318
# Epoch [   40/  100] | d_loss: 0.0325 | g_loss: 8.4729
# Epoch [   40/  100] | d_loss: 0.1138 | g_loss: 6.3827
# Epoch [   40/  100] | d_loss: 0.0309 | g_loss: 4.9241
# Epoch [   40/  100] | d_loss: 0.0309 | g_loss: 10.5403
# Epoch [   40/  100] | d_loss: 0.0518 | g_loss: 4.1149
# Epoch [   40/  100] | d_loss: 0.0117 | g_loss: 8.0994
# Epoch [   41/  100] | d_loss: 0.0034 | g_loss: 7.3243
# Epoch [   41/  100] | d_loss: 0.0337 | g_loss: 7.4986
# Epoch [   41/  100] | d_loss: 0.0078 | g_loss: 8.6885
# Epoch [   41/  100] | d_loss: 0.0475 | g_loss: 9.0056
# Epoch [   41/  100] | d_loss: 1.3609 | g_loss: 2.7553
# Epoch [   41/  100] | d_loss: 0.6154 | g_loss: 5.2954
# Epoch [   42/  100] | d_loss: 0.0326 | g_loss: 6.7947
# Epoch [   42/  100] | d_loss: 0.0114 | g_loss: 6.5780
# Epoch [   42/  100] | d_loss: 0.0333 | g_loss: 5.6908
# Epoch [   42/  100] | d_loss: 0.0654 | g_loss: 3.7100
# Epoch [   42/  100] | d_loss: 0.0192 | g_loss: 5.3117
# Epoch [   42/  100] | d_loss: 0.0741 | g_loss: 7.8992
# Epoch [   43/  100] | d_loss: 0.1744 | g_loss: 6.0763
# Epoch [   43/  100] | d_loss: 0.0121 | g_loss: 7.0984
# Epoch [   43/  100] | d_loss: 0.0059 | g_loss: 7.0520
# Epoch [   43/  100] | d_loss: 0.0245 | g_loss: 8.1833
# Epoch [   43/  100] | d_loss: 0.0669 | g_loss: 7.2978
# Epoch [   43/  100] | d_loss: 0.0334 | g_loss: 7.7190
# Epoch [   44/  100] | d_loss: 0.0440 | g_loss: 5.0353
# Epoch [   44/  100] | d_loss: 0.0089 | g_loss: 7.5948
# Epoch [   44/  100] | d_loss: 0.1526 | g_loss: 6.5876
# Epoch [   44/  100] | d_loss: 0.0052 | g_loss: 7.0689
# Epoch [   44/  100] | d_loss: 0.0061 | g_loss: 9.0919
# Epoch [   44/  100] | d_loss: 0.0271 | g_loss: 9.2025
# Epoch [   45/  100] | d_loss: 0.0054 | g_loss: 7.9207
# Epoch [   45/  100] | d_loss: 0.1266 | g_loss: 7.4841
# Epoch [   45/  100] | d_loss: 0.0120 | g_loss: 7.9450
# Epoch [   45/  100] | d_loss: 0.0096 | g_loss: 7.3358
# Epoch [   45/  100] | d_loss: 0.0135 | g_loss: 6.3911
# Epoch [   45/  100] | d_loss: 0.0149 | g_loss: 7.6698
# Epoch [   46/  100] | d_loss: 0.0179 | g_loss: 8.4701
# Epoch [   46/  100] | d_loss: 0.0244 | g_loss: 9.3640
# Epoch [   46/  100] | d_loss: 0.0561 | g_loss: 6.5148
# Epoch [   46/  100] | d_loss: 0.0317 | g_loss: 8.1729
# Epoch [   46/  100] | d_loss: 0.0053 | g_loss: 7.3682
# Epoch [   46/  100] | d_loss: 0.0273 | g_loss: 9.1198
# Epoch [   47/  100] | d_loss: 0.0520 | g_loss: 7.6004
# Epoch [   47/  100] | d_loss: 0.0426 | g_loss: 9.1525
# Epoch [   47/  100] | d_loss: 0.0056 | g_loss: 8.5337
# Epoch [   47/  100] | d_loss: 0.0029 | g_loss: 8.0433
# Epoch [   47/  100] | d_loss: 0.0239 | g_loss: 5.9536
# Epoch [   47/  100] | d_loss: 0.0049 | g_loss: 9.3138
# Epoch [   48/  100] | d_loss: 0.0033 | g_loss: 6.6415
# Epoch [   48/  100] | d_loss: 0.0708 | g_loss: 7.7149
# Epoch [   48/  100] | d_loss: 0.0047 | g_loss: 10.6560
# Epoch [   48/  100] | d_loss: 0.0097 | g_loss: 10.1646
# Epoch [   48/  100] | d_loss: 0.0368 | g_loss: 7.5497
# Epoch [   48/  100] | d_loss: 0.0992 | g_loss: 5.0631
# Epoch [   49/  100] | d_loss: 0.0772 | g_loss: 8.1997
# Epoch [   49/  100] | d_loss: 0.0031 | g_loss: 7.9176
# Epoch [   49/  100] | d_loss: 0.0213 | g_loss: 7.7737
# Epoch [   49/  100] | d_loss: 0.0151 | g_loss: 9.8270
# Epoch [   49/  100] | d_loss: 0.0043 | g_loss: 8.1670
# Epoch [   49/  100] | d_loss: 0.0036 | g_loss: 10.3212
# Epoch [   50/  100] | d_loss: 0.0055 | g_loss: 9.3823
# Epoch [   50/  100] | d_loss: 0.0521 | g_loss: 6.8160
# Epoch [   50/  100] | d_loss: 0.0128 | g_loss: 8.1447
# Epoch [   50/  100] | d_loss: 0.0166 | g_loss: 8.3463
# Epoch [   50/  100] | d_loss: 0.0123 | g_loss: 9.2646
# Epoch [   50/  100] | d_loss: 0.0018 | g_loss: 8.2533
# Epoch [   51/  100] | d_loss: 0.0210 | g_loss: 9.5569
# Epoch [   51/  100] | d_loss: 0.0265 | g_loss: 9.7330
# Epoch [   51/  100] | d_loss: 0.0089 | g_loss: 8.0279
# Epoch [   51/  100] | d_loss: 0.0215 | g_loss: 7.0411
# Epoch [   51/  100] | d_loss: 0.2352 | g_loss: 12.8138
# Epoch [   51/  100] | d_loss: 0.0067 | g_loss: 9.8565
# Epoch [   52/  100] | d_loss: 0.0050 | g_loss: 12.2029
# Epoch [   52/  100] | d_loss: 0.0191 | g_loss: 5.1059
# Epoch [   52/  100] | d_loss: 0.0026 | g_loss: 10.1614
# Epoch [   52/  100] | d_loss: 0.0050 | g_loss: 8.0710
# Epoch [   52/  100] | d_loss: 0.0043 | g_loss: 6.7409
# Epoch [   52/  100] | d_loss: 0.0139 | g_loss: 7.9067
# Epoch [   53/  100] | d_loss: 0.2329 | g_loss: 5.8527
# Epoch [   53/  100] | d_loss: 0.0115 | g_loss: 8.5958
# Epoch [   53/  100] | d_loss: 0.0053 | g_loss: 10.5742
# Epoch [   53/  100] | d_loss: 0.0039 | g_loss: 7.6498
# Epoch [   53/  100] | d_loss: 0.0035 | g_loss: 9.5501
# Epoch [   53/  100] | d_loss: 0.0043 | g_loss: 7.2514
# Epoch [   54/  100] | d_loss: 0.0176 | g_loss: 8.1934
# Epoch [   54/  100] | d_loss: 0.0293 | g_loss: 9.3162
# Epoch [   54/  100] | d_loss: 0.0040 | g_loss: 7.3100
# Epoch [   54/  100] | d_loss: 0.0330 | g_loss: 8.0586
# Epoch [   54/  100] | d_loss: 0.0015 | g_loss: 10.0211
# Epoch [   54/  100] | d_loss: 0.0022 | g_loss: 10.0035
# Epoch [   55/  100] | d_loss: 0.0059 | g_loss: 6.7182
# Epoch [   55/  100] | d_loss: 0.0103 | g_loss: 11.1937
# Epoch [   55/  100] | d_loss: 0.0021 | g_loss: 10.0948
# Epoch [   55/  100] | d_loss: 0.0072 | g_loss: 9.1579
# Epoch [   55/  100] | d_loss: 0.0384 | g_loss: 7.7834
# Epoch [   55/  100] | d_loss: 0.0008 | g_loss: 9.6565
# Epoch [   56/  100] | d_loss: 0.0114 | g_loss: 9.7672
# Epoch [   56/  100] | d_loss: 0.0127 | g_loss: 7.9218
# Epoch [   56/  100] | d_loss: 0.0023 | g_loss: 8.2882
# Epoch [   56/  100] | d_loss: 0.0098 | g_loss: 9.2426
# Epoch [   56/  100] | d_loss: 0.0049 | g_loss: 4.6569
# Epoch [   56/  100] | d_loss: 0.0051 | g_loss: 8.7738
# Epoch [   57/  100] | d_loss: 0.0233 | g_loss: 6.1877
# Epoch [   57/  100] | d_loss: 0.1191 | g_loss: 7.4645
# Epoch [   57/  100] | d_loss: 0.0124 | g_loss: 10.8756
# Epoch [   57/  100] | d_loss: 0.0081 | g_loss: 10.1506
# Epoch [   57/  100] | d_loss: 0.0080 | g_loss: 9.1117
# Epoch [   57/  100] | d_loss: 0.0012 | g_loss: 7.6337
# Epoch [   58/  100] | d_loss: 0.0076 | g_loss: 7.3147
# Epoch [   58/  100] | d_loss: 0.0253 | g_loss: 8.3058
# Epoch [   58/  100] | d_loss: 0.0026 | g_loss: 8.0368
# Epoch [   58/  100] | d_loss: 0.0530 | g_loss: 9.6015
# Epoch [   58/  100] | d_loss: 0.0334 | g_loss: 9.3500
# Epoch [   58/  100] | d_loss: 0.0140 | g_loss: 9.5755
# Epoch [   59/  100] | d_loss: 0.0273 | g_loss: 7.3657
# Epoch [   59/  100] | d_loss: 0.0097 | g_loss: 8.5221
# Epoch [   59/  100] | d_loss: 0.0174 | g_loss: 8.1374
# Epoch [   59/  100] | d_loss: 0.0079 | g_loss: 11.0259
# Epoch [   59/  100] | d_loss: 0.0319 | g_loss: 10.9541
# Epoch [   59/  100] | d_loss: 0.0065 | g_loss: 7.5463
# Epoch [   60/  100] | d_loss: 0.0291 | g_loss: 8.1014
# Epoch [   60/  100] | d_loss: 0.0202 | g_loss: 9.7183
# Epoch [   60/  100] | d_loss: 0.0106 | g_loss: 9.3772
# Epoch [   60/  100] | d_loss: 0.0072 | g_loss: 9.8588
# Epoch [   60/  100] | d_loss: 0.0026 | g_loss: 10.6988
# Epoch [   60/  100] | d_loss: 0.0113 | g_loss: 8.7346
# Epoch [   61/  100] | d_loss: 0.0186 | g_loss: 9.9494
# Epoch [   61/  100] | d_loss: 0.0260 | g_loss: 10.5426
# Epoch [   61/  100] | d_loss: 0.0017 | g_loss: 9.4917
# Epoch [   61/  100] | d_loss: 0.0285 | g_loss: 10.2828
# Epoch [   61/  100] | d_loss: 0.0071 | g_loss: 8.3926
# Epoch [   61/  100] | d_loss: 0.0027 | g_loss: 9.6766
# Epoch [   62/  100] | d_loss: 0.0163 | g_loss: 9.4434
# Epoch [   62/  100] | d_loss: 0.0041 | g_loss: 9.0653
# Epoch [   62/  100] | d_loss: 0.0274 | g_loss: 10.7132
# Epoch [   62/  100] | d_loss: 0.0036 | g_loss: 10.5718
# Epoch [   62/  100] | d_loss: 0.0838 | g_loss: 9.2624
# Epoch [   62/  100] | d_loss: 0.0026 | g_loss: 8.2719
# Epoch [   63/  100] | d_loss: 0.0301 | g_loss: 9.5545
# Epoch [   63/  100] | d_loss: 0.0073 | g_loss: 7.5659
# Epoch [   63/  100] | d_loss: 0.0022 | g_loss: 10.8277
# Epoch [   63/  100] | d_loss: 0.0020 | g_loss: 11.0096
# Epoch [   63/  100] | d_loss: 0.0127 | g_loss: 9.5523
# Epoch [   63/  100] | d_loss: 0.0449 | g_loss: 8.5701
# Epoch [   64/  100] | d_loss: 0.0053 | g_loss: 12.1434
# Epoch [   64/  100] | d_loss: 0.0233 | g_loss: 10.4567
# Epoch [   64/  100] | d_loss: 0.0101 | g_loss: 9.8976
# Epoch [   64/  100] | d_loss: 0.0027 | g_loss: 8.2434
# Epoch [   64/  100] | d_loss: 0.0084 | g_loss: 8.9114
# Epoch [   64/  100] | d_loss: 0.0150 | g_loss: 9.8293
# Epoch [   65/  100] | d_loss: 0.0034 | g_loss: 10.4297
# Epoch [   65/  100] | d_loss: 0.0160 | g_loss: 9.2022
# Epoch [   65/  100] | d_loss: 0.0264 | g_loss: 9.1174
# Epoch [   65/  100] | d_loss: 0.0023 | g_loss: 8.7158
# Epoch [   65/  100] | d_loss: 0.0101 | g_loss: 10.4373
# Epoch [   65/  100] | d_loss: 0.0023 | g_loss: 9.1851
# Epoch [   66/  100] | d_loss: 0.0051 | g_loss: 10.0614
# Epoch [   66/  100] | d_loss: 0.0263 | g_loss: 11.1657
# Epoch [   66/  100] | d_loss: 0.0020 | g_loss: 10.7847
# Epoch [   66/  100] | d_loss: 0.0010 | g_loss: 11.4538
# Epoch [   66/  100] | d_loss: 0.0195 | g_loss: 8.5468
# Epoch [   66/  100] | d_loss: 0.0032 | g_loss: 8.5292
# Epoch [   67/  100] | d_loss: 0.0007 | g_loss: 11.2303
# Epoch [   67/  100] | d_loss: 0.0007 | g_loss: 12.5588
# Epoch [   67/  100] | d_loss: 0.0055 | g_loss: 8.8270
# Epoch [   67/  100] | d_loss: 0.0105 | g_loss: 7.9945
# Epoch [   67/  100] | d_loss: 0.0071 | g_loss: 11.2773
# Epoch [   67/  100] | d_loss: 0.0007 | g_loss: 11.9944
# Epoch [   68/  100] | d_loss: 0.0164 | g_loss: 7.9429
# Epoch [   68/  100] | d_loss: 0.0229 | g_loss: 9.3964
# Epoch [   68/  100] | d_loss: 0.0004 | g_loss: 9.2648
# Epoch [   68/  100] | d_loss: 0.0021 | g_loss: 8.3693
# Epoch [   68/  100] | d_loss: 0.0058 | g_loss: 9.2069
# Epoch [   68/  100] | d_loss: 0.0052 | g_loss: 12.4750
# Epoch [   69/  100] | d_loss: 0.0156 | g_loss: 9.1017
# Epoch [   69/  100] | d_loss: 0.0424 | g_loss: 9.5391
# Epoch [   69/  100] | d_loss: 0.0062 | g_loss: 10.5464
# Epoch [   69/  100] | d_loss: 0.0041 | g_loss: 8.5823
# Epoch [   69/  100] | d_loss: 0.0025 | g_loss: 9.5902
# Epoch [   69/  100] | d_loss: 0.0065 | g_loss: 7.0002
# Epoch [   70/  100] | d_loss: 0.0054 | g_loss: 10.5127
# Epoch [   70/  100] | d_loss: 0.0063 | g_loss: 12.0567
# Epoch [   70/  100] | d_loss: 0.0009 | g_loss: 8.4719
# Epoch [   70/  100] | d_loss: 0.0301 | g_loss: 8.2494
# Epoch [   70/  100] | d_loss: 0.0629 | g_loss: 9.3064
# Epoch [   70/  100] | d_loss: 0.0065 | g_loss: 10.4788
# Epoch [   71/  100] | d_loss: 0.0075 | g_loss: 9.5830
# Epoch [   71/  100] | d_loss: 0.0085 | g_loss: 10.6663
# Epoch [   71/  100] | d_loss: 0.0053 | g_loss: 9.4226
# Epoch [   71/  100] | d_loss: 0.0040 | g_loss: 7.9535
# Epoch [   71/  100] | d_loss: 0.0091 | g_loss: 10.5658
# Epoch [   71/  100] | d_loss: 0.0011 | g_loss: 10.2410
# Epoch [   72/  100] | d_loss: 0.0363 | g_loss: 5.4812
# Epoch [   72/  100] | d_loss: 0.0021 | g_loss: 8.2319
# Epoch [   72/  100] | d_loss: 0.0252 | g_loss: 5.2588
# Epoch [   72/  100] | d_loss: 0.0479 | g_loss: 8.8213
# Epoch [   72/  100] | d_loss: 0.0009 | g_loss: 11.0761
# Epoch [   72/  100] | d_loss: 0.0041 | g_loss: 12.0275
# Epoch [   73/  100] | d_loss: 0.0028 | g_loss: 9.9504
# Epoch [   73/  100] | d_loss: 0.0204 | g_loss: 8.2046
# Epoch [   73/  100] | d_loss: 0.0045 | g_loss: 9.3802
# Epoch [   73/  100] | d_loss: 0.0024 | g_loss: 8.7736
# Epoch [   73/  100] | d_loss: 0.0019 | g_loss: 10.8963
# Epoch [   73/  100] | d_loss: 0.0036 | g_loss: 10.2798
# Epoch [   74/  100] | d_loss: 0.0014 | g_loss: 9.5444
# Epoch [   74/  100] | d_loss: 0.0380 | g_loss: 3.7556
# Epoch [   74/  100] | d_loss: 0.0024 | g_loss: 9.4736
# Epoch [   74/  100] | d_loss: 0.0072 | g_loss: 10.2936
# Epoch [   74/  100] | d_loss: 0.0143 | g_loss: 9.7785
# Epoch [   74/  100] | d_loss: 0.0019 | g_loss: 8.2253
# Epoch [   75/  100] | d_loss: 0.0007 | g_loss: 10.1552
# Epoch [   75/  100] | d_loss: 0.0042 | g_loss: 8.7840
# Epoch [   75/  100] | d_loss: 0.0031 | g_loss: 10.3195
# Epoch [   75/  100] | d_loss: 0.0055 | g_loss: 12.5322
# Epoch [   75/  100] | d_loss: 0.0046 | g_loss: 8.8824
# Epoch [   75/  100] | d_loss: 0.0141 | g_loss: 11.4037
# Epoch [   76/  100] | d_loss: 0.0008 | g_loss: 8.2218
# Epoch [   76/  100] | d_loss: 0.0011 | g_loss: 11.0704
# Epoch [   76/  100] | d_loss: 0.0050 | g_loss: 12.5840
# Epoch [   76/  100] | d_loss: 0.0035 | g_loss: 7.9944
# Epoch [   76/  100] | d_loss: 0.0016 | g_loss: 11.1309
# Epoch [   76/  100] | d_loss: 0.0195 | g_loss: 9.0684
# Epoch [   77/  100] | d_loss: 0.0018 | g_loss: 10.9468
# Epoch [   77/  100] | d_loss: 0.0030 | g_loss: 10.2002
# Epoch [   77/  100] | d_loss: 0.0042 | g_loss: 9.6397
# Epoch [   77/  100] | d_loss: 0.0029 | g_loss: 10.8879
# Epoch [   77/  100] | d_loss: 0.0007 | g_loss: 11.8934
# Epoch [   77/  100] | d_loss: 0.0039 | g_loss: 10.4130
# Epoch [   78/  100] | d_loss: 0.0013 | g_loss: 13.1497
# Epoch [   78/  100] | d_loss: 0.0015 | g_loss: 12.4147
# Epoch [   78/  100] | d_loss: 0.0026 | g_loss: 9.9522
# Epoch [   78/  100] | d_loss: 0.0028 | g_loss: 10.0635
# Epoch [   78/  100] | d_loss: 0.0008 | g_loss: 11.1458
# Epoch [   78/  100] | d_loss: 0.0018 | g_loss: 10.6073
# Epoch [   79/  100] | d_loss: 0.0421 | g_loss: 9.4356
# Epoch [   79/  100] | d_loss: 0.0033 | g_loss: 10.3845
# Epoch [   79/  100] | d_loss: 0.0004 | g_loss: 10.8232
# Epoch [   79/  100] | d_loss: 0.0057 | g_loss: 11.4893
# Epoch [   79/  100] | d_loss: 0.0004 | g_loss: 9.3730
# Epoch [   79/  100] | d_loss: 0.0020 | g_loss: 8.3959
# Epoch [   80/  100] | d_loss: 0.0080 | g_loss: 9.2846
# Epoch [   80/  100] | d_loss: 0.0345 | g_loss: 10.5255
# Epoch [   80/  100] | d_loss: 0.0322 | g_loss: 8.5204
# Epoch [   80/  100] | d_loss: 0.0029 | g_loss: 10.0119
# Epoch [   80/  100] | d_loss: 0.0023 | g_loss: 11.1381
# Epoch [   80/  100] | d_loss: 0.0029 | g_loss: 10.5265
# Epoch [   81/  100] | d_loss: 0.0007 | g_loss: 10.2244
# Epoch [   81/  100] | d_loss: 0.0007 | g_loss: 10.1132
# Epoch [   81/  100] | d_loss: 0.0017 | g_loss: 11.3763
# Epoch [   81/  100] | d_loss: 0.0315 | g_loss: 14.7228
# Epoch [   81/  100] | d_loss: 0.0077 | g_loss: 10.3152
# Epoch [   81/  100] | d_loss: 0.0038 | g_loss: 13.9849
# Epoch [   82/  100] | d_loss: 0.0049 | g_loss: 14.6396
# Epoch [   82/  100] | d_loss: 0.0003 | g_loss: 14.5541
# Epoch [   82/  100] | d_loss: 0.0002 | g_loss: 16.7991
# Epoch [   82/  100] | d_loss: 0.0002 | g_loss: 13.4104
# Epoch [   82/  100] | d_loss: 0.0002 | g_loss: 14.9317
# Epoch [   82/  100] | d_loss: 0.0176 | g_loss: 8.7826
# Epoch [   83/  100] | d_loss: 0.0007 | g_loss: 10.6840
# Epoch [   83/  100] | d_loss: 0.0002 | g_loss: 17.0293
# Epoch [   83/  100] | d_loss: 0.0010 | g_loss: 13.4220
# Epoch [   83/  100] | d_loss: 0.0000 | g_loss: 16.3244
# Epoch [   83/  100] | d_loss: 0.0010 | g_loss: 11.8781
# Epoch [   83/  100] | d_loss: 0.0006 | g_loss: 12.2485
# Epoch [   84/  100] | d_loss: 0.0008 | g_loss: 12.0119
# Epoch [   84/  100] | d_loss: 0.0002 | g_loss: 6.7186
# Epoch [   84/  100] | d_loss: 0.0001 | g_loss: 8.8475
# Epoch [   84/  100] | d_loss: 0.0026 | g_loss: 16.9792
# Epoch [   84/  100] | d_loss: 0.0022 | g_loss: 15.6761
# Epoch [   84/  100] | d_loss: 0.0010 | g_loss: 16.7307
# Epoch [   85/  100] | d_loss: 0.0000 | g_loss: 8.8972
# Epoch [   85/  100] | d_loss: 0.0000 | g_loss: 17.0684
# Epoch [   85/  100] | d_loss: 0.0006 | g_loss: 13.8597
# Epoch [   85/  100] | d_loss: 0.0002 | g_loss: 11.9578
# Epoch [   85/  100] | d_loss: 0.0003 | g_loss: 11.1042
# Epoch [   85/  100] | d_loss: 0.0000 | g_loss: 11.3541
# Epoch [   86/  100] | d_loss: 0.0000 | g_loss: 14.1017
# Epoch [   86/  100] | d_loss: 0.0001 | g_loss: 9.4314
# Epoch [   86/  100] | d_loss: 0.0005 | g_loss: 10.0926
# Epoch [   86/  100] | d_loss: 0.0002 | g_loss: 13.3149
# Epoch [   86/  100] | d_loss: 0.0001 | g_loss: 13.3810
# Epoch [   86/  100] | d_loss: 0.0000 | g_loss: 14.3226
# Epoch [   87/  100] | d_loss: 0.0002 | g_loss: 14.7491
# Epoch [   87/  100] | d_loss: 0.0000 | g_loss: 18.3654
# Epoch [   87/  100] | d_loss: 0.0001 | g_loss: 11.9761
# Epoch [   87/  100] | d_loss: 0.0001 | g_loss: 13.0789
# Epoch [   87/  100] | d_loss: 0.0001 | g_loss: 13.1447
# Epoch [   87/  100] | d_loss: 0.0001 | g_loss: 12.5432
# Epoch [   88/  100] | d_loss: 0.0000 | g_loss: 12.7583
# Epoch [   88/  100] | d_loss: 0.0000 | g_loss: 13.0797
# Epoch [   88/  100] | d_loss: 0.0000 | g_loss: 11.0441
# Epoch [   88/  100] | d_loss: 0.0000 | g_loss: 13.6313
# Epoch [   88/  100] | d_loss: 0.0001 | g_loss: 13.8551
# Epoch [   88/  100] | d_loss: 0.0001 | g_loss: 11.1520
# Epoch [   89/  100] | d_loss: 0.0002 | g_loss: 10.2313
# Epoch [   89/  100] | d_loss: 0.0003 | g_loss: 22.3756
# Epoch [   89/  100] | d_loss: 0.0001 | g_loss: 17.6718
# Epoch [   89/  100] | d_loss: 0.0000 | g_loss: 12.9007
# Epoch [   89/  100] | d_loss: 0.0002 | g_loss: 14.3602
# Epoch [   89/  100] | d_loss: 0.0000 | g_loss: 13.5663
# Epoch [   90/  100] | d_loss: 0.0000 | g_loss: 16.2520
# Epoch [   90/  100] | d_loss: 0.0000 | g_loss: 11.6986
# Epoch [   90/  100] | d_loss: 0.0000 | g_loss: 15.6860
# Epoch [   90/  100] | d_loss: 0.0000 | g_loss: 12.1326
# Epoch [   90/  100] | d_loss: 0.0001 | g_loss: 11.7183
# Epoch [   90/  100] | d_loss: 0.0000 | g_loss: 13.1715
# Epoch [   91/  100] | d_loss: 0.0002 | g_loss: 14.8207
# Epoch [   91/  100] | d_loss: 0.0006 | g_loss: 18.6488
# Epoch [   91/  100] | d_loss: 0.0000 | g_loss: 15.0756
# Epoch [   91/  100] | d_loss: 0.0001 | g_loss: 16.7675
# Epoch [   91/  100] | d_loss: 0.0000 | g_loss: 14.6662
# Epoch [   91/  100] | d_loss: 0.0000 | g_loss: 17.6553
# Epoch [   92/  100] | d_loss: 0.0000 | g_loss: 19.6945
# Epoch [   92/  100] | d_loss: 0.0000 | g_loss: 21.0291
# Epoch [   92/  100] | d_loss: 0.0000 | g_loss: 20.4129
# Epoch [   92/  100] | d_loss: 0.0000 | g_loss: 29.3478
# Epoch [   92/  100] | d_loss: 0.0000 | g_loss: 24.4613
# Epoch [   92/  100] | d_loss: 0.0000 | g_loss: 21.1768
# Epoch [   93/  100] | d_loss: 0.0001 | g_loss: 20.8774
# Epoch [   93/  100] | d_loss: 0.0000 | g_loss: 16.4449
# Epoch [   93/  100] | d_loss: 0.0000 | g_loss: 13.9825
# Epoch [   93/  100] | d_loss: 0.0001 | g_loss: 14.9085
# Epoch [   93/  100] | d_loss: 0.0000 | g_loss: 18.7940
# Epoch [   93/  100] | d_loss: 0.0000 | g_loss: 15.1175
# Epoch [   94/  100] | d_loss: 0.0000 | g_loss: 14.1984
# Epoch [   94/  100] | d_loss: 0.0000 | g_loss: 15.1239
# Epoch [   94/  100] | d_loss: 0.0000 | g_loss: 15.7138
# Epoch [   94/  100] | d_loss: 0.0000 | g_loss: 16.1221
# Epoch [   94/  100] | d_loss: 0.0001 | g_loss: 14.8561
# Epoch [   94/  100] | d_loss: 0.0000 | g_loss: 14.7670
# Epoch [   95/  100] | d_loss: 0.0000 | g_loss: 14.4042
# Epoch [   95/  100] | d_loss: 0.0000 | g_loss: 15.7233
# Epoch [   95/  100] | d_loss: 0.0000 | g_loss: 13.7708
# Epoch [   95/  100] | d_loss: 0.0000 | g_loss: 14.3120
# Epoch [   95/  100] | d_loss: 0.0000 | g_loss: 13.4654
# Epoch [   95/  100] | d_loss: 0.0000 | g_loss: 17.2862
# Epoch [   96/  100] | d_loss: 0.0000 | g_loss: 16.4047
# Epoch [   96/  100] | d_loss: 0.0000 | g_loss: 17.1566
# Epoch [   96/  100] | d_loss: 0.0000 | g_loss: 15.2240
# Epoch [   96/  100] | d_loss: 0.0000 | g_loss: 15.4419
# Epoch [   96/  100] | d_loss: 0.0000 | g_loss: 17.8177
# Epoch [   96/  100] | d_loss: 0.0000 | g_loss: 13.9104
# Epoch [   97/  100] | d_loss: 0.0000 | g_loss: 14.8224
# Epoch [   97/  100] | d_loss: 0.0000 | g_loss: 20.5681
# Epoch [   97/  100] | d_loss: 0.0000 | g_loss: 16.6459
# Epoch [   97/  100] | d_loss: 0.0000 | g_loss: 14.9809
# Epoch [   97/  100] | d_loss: 0.0000 | g_loss: 17.2467
# Epoch [   97/  100] | d_loss: 0.0000 | g_loss: 16.8704
# Epoch [   98/  100] | d_loss: 0.0000 | g_loss: 15.5046
# Epoch [   98/  100] | d_loss: 0.0000 | g_loss: 15.0637
# Epoch [   98/  100] | d_loss: 0.0000 | g_loss: 15.2407
# Epoch [   98/  100] | d_loss: 0.0000 | g_loss: 16.0147
# Epoch [   98/  100] | d_loss: 0.0000 | g_loss: 16.2170
# Epoch [   98/  100] | d_loss: 0.0000 | g_loss: 19.9633
# Epoch [   99/  100] | d_loss: 0.0000 | g_loss: 15.4368
# Epoch [   99/  100] | d_loss: 0.0000 | g_loss: 14.3227
# Epoch [   99/  100] | d_loss: 0.0000 | g_loss: 15.7070
# Epoch [   99/  100] | d_loss: 0.0000 | g_loss: 15.0264
# Epoch [   99/  100] | d_loss: 0.0000 | g_loss: 22.8497
# Epoch [   99/  100] | d_loss: 0.0000 | g_loss: 17.3153
# Epoch [  100/  100] | d_loss: 0.0000 | g_loss: 16.9201
# Epoch [  100/  100] | d_loss: 0.0000 | g_loss: 15.6615
# Epoch [  100/  100] | d_loss: 0.0000 | g_loss: 15.0248
# Epoch [  100/  100] | d_loss: 0.0000 | g_loss: 17.5018
# Epoch [  100/  100] | d_loss: 0.0000 | g_loss: 18.3285
# Epoch [  100/  100] | d_loss: 0.0000 | g_loss: 14.8254

# %% [markdown]
# ## Training loss
#
# Here we'll plot the training losses for the generator and discriminator, recorded after each epoch.

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
plt.plot(losses.T[1], label='Generator', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %%
# Take a look at some fake images generated during traning

# helper function for viewing a list of images, for us they are intermediate fake images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img +1)*255 / (2)).astype(np.uint8) # rescale to pixel range (0-255)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))

# %%
_ = view_samples(-1, samples)
